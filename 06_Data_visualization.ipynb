# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# Load the dataset
df = sns.load_dataset('titanic')

# %%
# why we use scatter plot?
# A scatter plot is used to visualize the relationship between two numerical variables.
df.plot(kind='scatter', x='age', y='fare', color='red')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
# why we use bar plot?
# A bar plot is used to compare the average age of passengers
df.groupby('sex')['age'].mean().plot(kind='bar', color=['red', 'green'])
plt.title('Average Age of Passengers')
plt.ylabel('Average Age')
plt.xlabel('Gender')
# Out:
# Text(0.5, 0, 'Gender')

# %%
# why we use pie chart?
# A pie chart is used to show the population of male and femnale passengers.
plt.figure(figsize=(8, 6))
sns.set_style('whitegrid')
plt.subplot(1, 1, 1)
df['sex'].value_counts().plot(kind='pie')
plt.title('Count of male and female')
# Out:
# Text(0.5, 1.0, 'Count of male and female')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # **Plots using seaborn**

# %%
# Scatter plot showing the relationship between passenger age and fare
# Data points are colored by passenger class to identify patterns
sns.scatterplot(data=df, x='age', y='fare', hue='class')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
# pip install plotly
# !pip install nbformat
#

# %%
pig = px.scatter(df, x='age' , y='fare', color='sex', title='Scatter Plot of Age vs Fare by Class')
pig.show()
